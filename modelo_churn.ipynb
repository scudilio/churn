# %% [markdown]
# <a href="https://colab.research.google.com/github/scudilio/churn/blob/main/modelo_churn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MODELO DE CHURN**

# %% [markdown]
# ##**1. Introdução**
#
# Empresas que têm a cultura data driven maximizam seus resultados através de informações extraídas dos dados. Ou seja, utilizam os dados para extrair informações e usam as informações para tomar decisões.
#
# "Seus clientes mais insatisfeitos são sua maior fonte de aprendizado (Bill Gates)."
#
# A taxa de retenção de clientes é um bom indicativo de qualidade do seu produto/serviço. Se o produto/serviço não é de qualidade, você irá observar uma porcentagem alta de clientes deixando de comprar ou trocando de empresa, ou seja, uma alta taxa de Churn.
#
# Mas quais são as características que leva um cliente a dar o Churn?
#
# Na parte I, desse tutorial, entendemos o problema de Churn e estabelecemos o objetivo, identificar o perfil e prever os clientes em risco de Churn.
#
# Agora nessa parte II daremos continuidade a análise e para isso utilizaremos um conjunto de dados de uma agência bancária.
#
# Recordando, para esse projeto de Data Science seguiremos essas etapas
#
# * Entendimento do Problema
# * Obtenção dos dados
# * Análise Exploratória e Visualização dos dados
# * Pré-processamento
# * Modelos de Machine Learning
# * Avaliação do modelo

# %% [markdown]
# #2.**Coleta de dados**

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Churn_Modelling.csv')
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
# 5       8  113755.78              2          1               0
# 6       7       0.00              2          1               1
# 7       4  115046.74              4          1               0
# 8       4  142051.07              2          0               1
# 9       2  134603.88              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0
# 5        149756.71       1
# 6         10062.80       0
# 7        119346.88       1
# 8         74940.50       0
# 9         71725.73       0

# %% [markdown]
# ## **3. EDA**

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.hist(figsize=(12,10));

# %% [markdown]
# ## **D.Visualização de Dados - Qual o perfil de clientes que cancelaram o contrato (Churn)?**

# %%
import numpy as np #  pacote algebra linear;
import seaborn as sns #visualização de dados;

# %%
myred='#CD5C5C'
myblue='#6495ED'
mygreen='#90EE90'
cols= [myred, myblue,mygreen]

# %%
# porcentagem de clientes que sairam do banco
df['Exited'].sum()/df['Exited'].count()
# Out:
# 0.2037

# %% [markdown]
# ###**Variáveis Categóricas**
#
#  Primeiro vamos analisar as variáveis categóricas em relação a variável de saída (Exited). Utilizaremos gráficos de barras para esse fim.
#
# * **Variável Sexo**

# %%
#renomeando as categorias
df['Gender'] = df['Gender'].replace(['Female','Male'],['Feminino','Masculino'])

# %%
df_plot = df.groupby ('Gender'). Exited.mean (). reset_index () 
df_plot
# Out:
#       Gender    Exited
# 0   Feminino  0.250715
# 1  Masculino  0.164559

# %%
#Sexo em relação a variável churn
x = df_plot['Gender']
y = df_plot['Exited']
plt.bar(x,y,color=cols);
plt.title('Taxa de Churn em relação ao Sexo');
plt.xlabel('Sexo');
plt.ylabel('Taxa de Churn');

# %% [markdown]
# Observa-se que as mulheres têm um risco maior de Churn do que os homens.
#
# * **Variável País**

# %%
df['Geography'] = df['Geography'].replace(['France','Germany','Spain'],['França','Alemanha','Espanha'])
df_plot = df.groupby ('Geography'). Exited.mean (). reset_index () 
df_plot
# Out:
#   Geography    Exited
# 0  Alemanha  0.324432
# 1   Espanha  0.166734
# 2    França  0.161548

# %%
#País em relação a variável churn
x = df_plot['Geography']
y = df_plot['Exited']
plt.bar(x,y,color=cols);
plt.title('Taxa de Churn em relação ao País');
plt.xlabel('País');
plt.ylabel('Taxa de Churn');

# %% [markdown]
# Em relação a variável país, observa-se que a porcentagem de Churn na Alemanha é bastante elevada, onde 32% dos clientes encerraram a conta no banco. Espanha e França têm uma taxa de Churn parecidas em torno de 16%.
#
# **Variável Cartão de Crédito**

# %%
df['HasCrCard'] = df['HasCrCard'].replace([0,1],['Não','Sim'])

# %%
df_plot = df.groupby ('HasCrCard'). Exited.mean (). reset_index () 
df_plot
# Out:
#   HasCrCard    Exited
# 0       Não  0.208149
# 1       Sim  0.201843

# %%
#Cartão de crédito em relação a variável churn
x = df_plot['HasCrCard']
y = df_plot['Exited']
plt.bar(x,y,color=cols);
plt.title('Taxa de Churn em relação a variável Cartão de Crédito');
plt.xlabel('Cartão de crédito');
plt.ylabel('Taxa de Churn');

# %% [markdown]
# Observe que o cliente ter ou não cartão de crédito parece não influenciar no Churn.
#
# * **Variável Membro Ativo**

# %%
df['IsActiveMember'] = df['IsActiveMember'].replace([0,1],['Não','Sim'])
df_plot = df.groupby ('IsActiveMember'). Exited.mean (). reset_index () 
#Membro ativo em relação a variável churn
x = df_plot['IsActiveMember']
y = df_plot['Exited']
plt.bar(x,y,color=cols);
plt.title('Taxa de Churn em relação a variável Membro Ativo');
plt.xlabel('Membro ativo');
plt.ylabel('Taxa de Churn');

# %% [markdown]
# O Churn entre os clientes que não são ativos é maior do que os clientes ativos, tendo uma diferença de aproximadamente 12%.
#
# Variáveis numéricas
# Para as variáveis numéricas utilizaremos variáveis de barras para variáveis discretas e gráfico de dispersão e box-plot para as variáveis contínuas. Também analisaremos a matriz de correlação para ver a correlação entre as variáveis.
#
# Selecionamos, primeiramente, apenas as variáveis numéricas

# %%
#box-plot salto bancario em relação ao Churn
cols = [myred, myblue,mygreen]
sns.boxplot(x = "Exited_cat", y="Balance", data=df,palette=cols);
plt.title('Box-plot da variável Saldo bancário');
plt.xlabel('Variável Churn');
plt.ylabel('Saldo Bancário');
df.groupby(['Exited_cat'])['Balance'].mean()
# Out:
# Exited_cat
# Não    72745.296779
# Sim    91108.539337
# Name: Balance, dtype: float64

# %%
#box-plot Idade pelo Churn
sns.boxplot(x = "Exited_cat", y = "Age" , data = df,palette = cols);
plt.xlabel('Churn');
plt.ylabel('Idade');
df.groupby(['Exited'])['Age'].mean()
# Out:
# Exited
# 0    37.408389
# 1    44.837997
# Name: Age, dtype: float64

# %% [markdown]
# Analisando o histórico de clientes, observamos algumas características entre os clientes que cancelaram o serviço.
#
# Observa-se que clientes da Alemanha, do sexo feminino, que não são membro ativo, com alto número de produtos, score de crédito baixo, com saldo bancário elevado e com idade entre 50 e 60 anos têm uma taxa de Churn maior que os outros clientes.
#
# Assim, clientes com essas características possui um risco maior de cancelarem o serviço bancário.

# %% [markdown]
# ## **4. PRÉ PROCESSAMENTO**
#
# Alguns algoritmos de machine learning não aceitam variáveis categóricas e por isso precisamos utilizar técnicas para converter as classes em números.
#
# Ou seja, convertemos as colunas categóricas em numéricas simplesmente atribuindo números inteiros a classes distintas.
#
# Para as variáveis categóricas com apenas duas classes utilizaremos a função Label Encoder para converte colunas categóricas em numéricas simplesmente atribuindo números inteiros a valores distintos.
#
# Por exemplo, a coluna sexo tem dois valores: Feminino e Masculino . Após aplicar a função, os valores serão transformados em 1 e 0.

# %%
df1 = df.drop(columns = ['RowNumber','CustomerId','Surname','Exited_cat'])
df1
# Out:
#       CreditScore Geography     Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    França   Feminino   42       2       0.00              1
# 1             608   Espanha   Feminino   41       1   83807.86              1
# 2             502    França   Feminino   42       8  159660.80              3
# 3             699    França   Feminino   39       1       0.00              2
# 4             850   Espanha   Feminino   43       2  125510.82              1
# ...           ...       ...        ...  ...     ...        ...            ...
# 9995          771    França  Masculino   39       5       0.00              2
# 9996          516    França  Masculino   35      10   57369.61              1
# 9997          709    França   Feminino   36       7       0.00              1
# 9998          772  Alemanha  Masculino   42       3   75075.31              2
# 9999          792    França   Feminino   28       4  130142.79              1
#
#      HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          Sim               1        101348.88       1
# 1          Não               1        112542.58       0
# 2          Sim               0        113931.57       1
# 3          Não               0         93826.63       0
# 4          Sim               1         79084.10       0
# ...        ...             ...              ...     ...
# 9995       Sim               0         96270.64       0
# 9996       Sim               1        101699.77       0
# 9997       Não               1         42085.58       1
# 9998       Sim               0         92888.52       1
# 9999       Sim               0         38190.78       0
#
# [10000 rows x 11 columns]

# %% [markdown]
# ##**Dados faltantes**

# %%
#Contato número de observações faltantes no dataset para cada variável
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# Exited_cat         0
# dtype: int64

# %%
y = df1['Exited']
X = df1
X = df1.drop('Exited',axis = 1)
X

# %%
#Variáveis Continuas
x_cont = ['CreditScore','Balance','Age','EstimatedSalary','Tenure']
x_cont
# Out:
# ['CreditScore', 'Balance', 'Age', 'EstimatedSalary', 'Tenure']

# %%
#Variáveis Categóricas
x_cat = list(set(X)-set(x_cont))
x_cat
x_dummies = X[x_cat]
x_dummies
# Out:
#      HasCrCard Geography  NumOfProducts  IsActiveMember     Gender
# 0          Sim    França              1               1   Feminino
# 1          Não   Espanha              1               1   Feminino
# 2          Sim    França              3               0   Feminino
# 3          Não    França              2               0   Feminino
# 4          Sim   Espanha              1               1   Feminino
# ...        ...       ...            ...             ...        ...
# 9995       Sim    França              2               0  Masculino
# 9996       Sim    França              1               1  Masculino
# 9997       Não    França              1               1   Feminino
# 9998       Sim  Alemanha              2               0  Masculino
# 9999       Sim    França              1               0   Feminino
#
# [10000 rows x 5 columns]

# %%
##Substituindo a variável sexo para 0 e 1
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X['Gender'] = le.fit_transform(X['Gender']) 
X.head(10)
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    França       0   42       2       0.00              1
# 1          608   Espanha       0   41       1   83807.86              1
# 2          502    França       0   42       8  159660.80              3
# 3          699    França       0   39       1       0.00              2
# 4          850   Espanha       0   43       2  125510.82              1
# 5          645   Espanha       1   44       8  113755.78              2
# 6          822    França       1   50       7       0.00              2
# 7          376  Alemanha       0   29       4  115046.74              4
# 8          501    França       1   44       4  142051.07              2
# 9          684    França       1   27       2  134603.88              1
#
#   HasCrCard  IsActiveMember  EstimatedSalary
# 0       Sim               1        101348.88
# 1       Não               1        112542.58
# 2       Sim               0        113931.57
# 3       Não               0         93826.63
# 4       Sim               1         79084.10
# 5       Sim               0        149756.71
# 6       Sim               1         10062.80
# 7       Sim               0        119346.88
# 8       Não               1         74940.50
# 9       Sim               1         71725.73

# %%
x_final = pd.get_dummies (data = X, columns=['Geography','NumOfProducts','HasCrCard'] )
x_final
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  IsActiveMember  \
# 0             619       0   42       2       0.00               1
# 1             608       0   41       1   83807.86               1
# 2             502       0   42       8  159660.80               0
# 3             699       0   39       1       0.00               0
# 4             850       0   43       2  125510.82               1
# ...           ...     ...  ...     ...        ...             ...
# 9995          771       1   39       5       0.00               0
# 9996          516       1   35      10   57369.61               1
# 9997          709       0   36       7       0.00               1
# 9998          772       1   42       3   75075.31               0
# 9999          792       0   28       4  130142.79               0
#
#       EstimatedSalary  Geography_Alemanha  Geography_Espanha  \
# 0           101348.88                   0                  0
# 1           112542.58                   0                  1
# 2           113931.57                   0                  0
# 3            93826.63                   0                  0
# 4            79084.10                   0                  1
# ...               ...                 ...                ...
# 9995         96270.64                   0                  0
# 9996        101699.77                   0                  0
# 9997         42085.58                   0                  0
# 9998         92888.52                   1                  0
# 9999         38190.78                   0                  0
#
#       Geography_França  NumOfProducts_1  NumOfProducts_2  NumOfProducts_3  \
# 0                    1                1                0                0
# 1                    0                1                0                0
# 2                    1                0                0                1
# 3                    1                0                1                0
# 4                    0                1                0                0
# ...                ...              ...              ...              ...
# 9995                 1                0                1                0
# 9996                 1                1                0                0
# 9997                 1                1                0                0
# 9998                 0                0                1                0
# 9999                 1                1                0                0
#
#       NumOfProducts_4  HasCrCard_Não  HasCrCard_Sim
# 0                   0              0              1
# 1                   0              1              0
# 2                   0              0              1
# 3                   0              1              0
# 4                   0              0              1
# ...               ...            ...            ...
# 9995                0              0              1
# 9996                0              0              1
# 9997                0              1              0
# 9998                0              0              1
# 9999                0              0              1
#
# [10000 rows x 16 columns]

# %%
# Separando em dados teste e treinamento 
from sklearn.model_selection import train_test_split 

x_treino, x_teste, y_treino,y_teste  = train_test_split(x_final, y, test_size = 0.25,random_state = 1)
x_treino
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  IsActiveMember  \
# 651           720       1   52       7       0.00               1
# 6560          577       0   32       1       0.00               0
# 8974          706       0   43       1       0.00               0
# 2348          824       1   45       3  129209.48               0
# 5670          497       1   32       8       0.00               0
# ...           ...     ...  ...     ...        ...             ...
# 2895          621       1   47       7  107363.29               1
# 7813          684       0   63       3   81245.79               0
# 905           672       0   45       9       0.00               1
# 5192          663       0   39       8       0.00               1
# 235           763       1   42       6  100160.75               0
#
#       EstimatedSalary  Geography_Alemanha  Geography_Espanha  \
# 651          14781.12                   0                  0
# 6560          9902.39                   0                  0
# 8974         31962.77                   0                  1
# 2348         60151.77                   0                  0
# 5670         67364.42                   0                  0
# ...               ...                 ...                ...
# 2895         66799.28                   1                  0
# 7813         69643.31                   1                  0
# 905          92027.69                   0                  0
# 5192        101168.90                   0                  0
# 235          33462.94                   1                  0
#
#       Geography_França  NumOfProducts_1  NumOfProducts_2  NumOfProducts_3  \
# 651                  1                1                0                0
# 6560                 1                0                1                0
# 8974                 0                0                1                0
# 2348                 1                1                0                0
# 5670                 1                0                1                0
# ...                ...              ...              ...              ...
# 2895                 0                1                0                0
# 7813                 0                1                0                0
# 905                  1                1                0                0
# 5192                 1                0                1                0
# 235                  0                1                0                0
#
#       NumOfProducts_4  HasCrCard_Não  HasCrCard_Sim
# 651                 0              0              1
# 6560                0              0              1
# 8974                0              0              1
# 2348                0              1              0
# 5670                0              0              1
# ...               ...            ...            ...
# 2895                0              0              1
# 7813                0              0              1
# 905                 0              0              1
# 5192                0              0              1
# 235                 0              0              1
#
# [7500 rows x 16 columns]

# %% [markdown]
# ## **5.MODELO**

# %%
from sklearn.tree import DecisionTreeClassifier
modelo = DecisionTreeClassifier() # Nunca faça isso!
modelo.fit(x_treino,y_treino)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## **6. AJUSTE**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

dt = DecisionTreeClassifier(random_state=61658)

params = {
    'criterion' : ['gini','entropy'],
    'max_depth' : [2,3,4,5,6,7,8,9],
}

grid = GridSearchCV(
    dt,
    params,
    cv=10,
    scoring='roc_auc', 
    verbose=10,
    n_jobs=1,
)

grid.fit(x_treino,y_treino)
# Out:
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
# [CV 1/10; 1/16] START criterion=gini, max_depth=2...............................
# [CV 1/10; 1/16] END criterion=gini, max_depth=2;, score=0.710 total time=   0.0s
# [CV 2/10; 1/16] START criterion=gini, max_depth=2...............................
# [CV 2/10; 1/16] END criterion=gini, max_depth=2;, score=0.728 total time=   0.0s
# [CV 3/10; 1/16] START criterion=gini, max_depth=2...............................
# [CV 3/10; 1/16] END criterion=gini, max_depth=2;, score=0.726 total time=   0.0s
# [CV 4/10; 1/16] START criterion=gini, max_depth=2...............................
# [CV 4/10; 1/16] END criterion=gini, max_depth=2;, score=0.729 total time=   0.0s
# [CV 5/10; 1/16] START criterion=gini, max_depth=2...............................
# [CV 5/10; 1/16] END criterion=gini, max_depth=2;, score=0.723 total time=   0.0s
# [CV 6/10; 1/16] START criterion=gini, max_depth=2...............................
# [CV 6/10; 1/16] END criterion=gini, max_depth=2;, score=0.701 total time=   0.0s
# [CV 7/10; 1/16] START criterion=gini, max_depth=2...............................
# [CV 7/10; 1/16] END criterion=gini, max_depth=2;, score=0.715 total time=   0.0s
# [CV 8/10; 1/16] START criterion=gini, max_depth=2...............................
# [CV 8/10; 1/16] END criterion=gini, max_depth=2;, score=0.752 total time=   0.0s
# [CV 9/10; 1/16] START criterion=gini, max_depth=2...............................
# [CV 9/10; 1/16] END criterion=gini, max_depth=2;, score=0.747 total time=   0.0s
# [CV 10/10; 1/16] START criterion=gini, max_depth=2..............................
# [CV 10/10; 1/16] END criterion=gini, max_depth=2;, score=0.722 total time=   0.0s
# [CV 1/10; 2/16] START criterion=gini, max_depth=3...............................
# [CV 1/10; 2/16] END criterion=gini, max_depth=3;, score=0.779 total time=   0.0s
# [CV 2/10; 2/16] START criterion=gini, max_depth=3...............................
# [CV 2/10; 2/16] END criterion=gini, max_depth=3;, score=0.806 total time=   0.0s
# [CV 3/10; 2/16] START criterion=gini, max_depth=3...............................
# [CV 3/10; 2/16] END criterion=gini, max_depth=3;, score=0.808 total time=   0.0s
# [CV 4/10; 2/16] START criterion=gini, max_depth=3...............................
# [CV 4/10; 2/16] END criterion=gini, max_depth=3;, score=0.788 total time=   0.0s
# [CV 5/10; 2/16] START criterion=gini, max_depth=3...............................
# [CV 5/10; 2/16] END criterion=gini, max_depth=3;, score=0.796 total time=   0.0s
# [CV 6/10; 2/16] START criterion=gini, max_depth=3...............................
# [CV 6/10; 2/16] END criterion=gini, max_depth=3;, score=0.765 total time=   0.0s
# [CV 7/10; 2/16] START criterion=gini, max_depth=3...............................
# [CV 7/10; 2/16] END criterion=gini, max_depth=3;, score=0.805 total time=   0.0s
# [CV 8/10; 2/16] START criterion=gini, max_depth=3...............................
# [CV 8/10; 2/16] END criterion=gini, max_depth=3;, score=0.823 total time=   0.0s
# [CV 9/10; 2/16] START criterion=gini, max_depth=3...............................
# [CV 9/10; 2/16] END criterion=gini, max_depth=3;, score=0.802 total time=   0.0s
# [CV 10/10; 2/16] START criterion=gini, max_depth=3..............................
# [CV 10/10; 2/16] END criterion=gini, max_depth=3;, score=0.789 total time=   0.0s
# [CV 1/10; 3/16] START criterion=gini, max_depth=4...............................
# [CV 1/10; 3/16] END criterion=gini, max_depth=4;, score=0.789 total time=   0.0s
# [CV 2/10; 3/16] START criterion=gini, max_depth=4...............................
# [CV 2/10; 3/16] END criterion=gini, max_depth=4;, score=0.838 total time=   0.0s
# [CV 3/10; 3/16] START criterion=gini, max_depth=4...............................
# [CV 3/10; 3/16] END criterion=gini, max_depth=4;, score=0.813 total time=   0.0s
# [CV 4/10; 3/16] START criterion=gini, max_depth=4...............................
# [CV 4/10; 3/16] END criterion=gini, max_depth=4;, score=0.803 total time=   0.0s
# [CV 5/10; 3/16] START criterion=gini, max_depth=4...............................
# [CV 5/10; 3/16] END criterion=gini, max_depth=4;, score=0.808 total time=   0.0s
# [CV 6/10; 3/16] START criterion=gini, max_depth=4...............................
# [CV 6/10; 3/16] END criterion=gini, max_depth=4;, score=0.786 total time=   0.0s
# [CV 7/10; 3/16] START criterion=gini, max_depth=4...............................
# [CV 7/10; 3/16] END criterion=gini, max_depth=4;, score=0.824 total time=   0.0s
# [CV 8/10; 3/16] START criterion=gini, max_depth=4...............................
# [CV 8/10; 3/16] END criterion=gini, max_depth=4;, score=0.832 total time=   0.0s
# [CV 9/10; 3/16] START criterion=gini, max_depth=4...............................
# [CV 9/10; 3/16] END criterion=gini, max_depth=4;, score=0.810 total time=   0.0s
# [CV 10/10; 3/16] START criterion=gini, max_depth=4..............................
# [CV 10/10; 3/16] END criterion=gini, max_depth=4;, score=0.803 total time=   0.0s
# [CV 1/10; 4/16] START criterion=gini, max_depth=5...............................
# [CV 1/10; 4/16] END criterion=gini, max_depth=5;, score=0.789 total time=   0.0s
# [CV 2/10; 4/16] START criterion=gini, max_depth=5...............................
# [CV 2/10; 4/16] END criterion=gini, max_depth=5;, score=0.850 total time=   0.0s
# [CV 3/10; 4/16] START criterion=gini, max_depth=5...............................
# [CV 3/10; 4/16] END criterion=gini, max_depth=5;, score=0.801 total time=   0.0s
# [CV 4/10; 4/16] START criterion=gini, max_depth=5...............................
# [CV 4/10; 4/16] END criterion=gini, max_depth=5;, score=0.814 total time=   0.0s
# [CV 5/10; 4/16] START criterion=gini, max_depth=5...............................
# [CV 5/10; 4/16] END criterion=gini, max_depth=5;, score=0.819 total time=   0.0s
# [CV 6/10; 4/16] START criterion=gini, max_depth=5...............................
# [CV 6/10; 4/16] END criterion=gini, max_depth=5;, score=0.800 total time=   0.0s
# [CV 7/10; 4/16] START criterion=gini, max_depth=5...............................
# [CV 7/10; 4/16] END criterion=gini, max_depth=5;, score=0.833 total time=   0.0s
# [CV 8/10; 4/16] START criterion=gini, max_depth=5...............................
# [CV 8/10; 4/16] END criterion=gini, max_depth=5;, score=0.839 total time=   0.0s
# [CV 9/10; 4/16] START criterion=gini, max_depth=5...............................
# [CV 9/10; 4/16] END criterion=gini, max_depth=5;, score=0.810 total time=   0.0s
# [CV 10/10; 4/16] START criterion=gini, max_depth=5..............................
# [CV 10/10; 4/16] END criterion=gini, max_depth=5;, score=0.811 total time=   0.0s
# [CV 1/10; 5/16] START criterion=gini, max_depth=6...............................
# [CV 1/10; 5/16] END criterion=gini, max_depth=6;, score=0.801 total time=   0.0s
# [CV 2/10; 5/16] START criterion=gini, max_depth=6...............................
# [CV 2/10; 5/16] END criterion=gini, max_depth=6;, score=0.857 total time=   0.0s
# [CV 3/10; 5/16] START criterion=gini, max_depth=6...............................
# [CV 3/10; 5/16] END criterion=gini, max_depth=6;, score=0.809 total time=   0.0s
# [CV 4/10; 5/16] START criterion=gini, max_depth=6...............................
# [CV 4/10; 5/16] END criterion=gini, max_depth=6;, score=0.818 total time=   0.0s
# [CV 5/10; 5/16] START criterion=gini, max_depth=6...............................
# [CV 5/10; 5/16] END criterion=gini, max_depth=6;, score=0.818 total time=   0.0s
# [CV 6/10; 5/16] START criterion=gini, max_depth=6...............................
# [CV 6/10; 5/16] END criterion=gini, max_depth=6;, score=0.805 total time=   0.0s
# [CV 7/10; 5/16] START criterion=gini, max_depth=6...............................
# [CV 7/10; 5/16] END criterion=gini, max_depth=6;, score=0.835 total time=   0.0s
# [CV 8/10; 5/16] START criterion=gini, max_depth=6...............................
# [CV 8/10; 5/16] END criterion=gini, max_depth=6;, score=0.821 total time=   0.0s
# [CV 9/10; 5/16] START criterion=gini, max_depth=6...............................
# [CV 9/10; 5/16] END criterion=gini, max_depth=6;, score=0.829 total time=   0.0s
# [CV 10/10; 5/16] START criterion=gini, max_depth=6..............................
# [CV 10/10; 5/16] END criterion=gini, max_depth=6;, score=0.830 total time=   0.0s
# [CV 1/10; 6/16] START criterion=gini, max_depth=7...............................
# [CV 1/10; 6/16] END criterion=gini, max_depth=7;, score=0.813 total time=   0.0s
# [CV 2/10; 6/16] START criterion=gini, max_depth=7...............................
# [CV 2/10; 6/16] END criterion=gini, max_depth=7;, score=0.852 total time=   0.0s
# [CV 3/10; 6/16] START criterion=gini, max_depth=7...............................
# [CV 3/10; 6/16] END criterion=gini, max_depth=7;, score=0.794 total time=   0.0s
# [CV 4/10; 6/16] START criterion=gini, max_depth=7...............................
# [CV 4/10; 6/16] END criterion=gini, max_depth=7;, score=0.817 total time=   0.0s
# [CV 5/10; 6/16] START criterion=gini, max_depth=7...............................
# [CV 5/10; 6/16] END criterion=gini, max_depth=7;, score=0.800 total time=   0.0s
# [CV 6/10; 6/16] START criterion=gini, max_depth=7...............................
# [CV 6/10; 6/16] END criterion=gini, max_depth=7;, score=0.791 total time=   0.0s
# [CV 7/10; 6/16] START criterion=gini, max_depth=7...............................
# [CV 7/10; 6/16] END criterion=gini, max_depth=7;, score=0.816 total time=   0.0s
# [CV 8/10; 6/16] START criterion=gini, max_depth=7...............................
# [CV 8/10; 6/16] END criterion=gini, max_depth=7;, score=0.796 total time=   0.0s
# [CV 9/10; 6/16] START criterion=gini, max_depth=7...............................
# [CV 9/10; 6/16] END criterion=gini, max_depth=7;, score=0.831 total time=   0.0s
# [CV 10/10; 6/16] START criterion=gini, max_depth=7..............................
# [CV 10/10; 6/16] END criterion=gini, max_depth=7;, score=0.821 total time=   0.0s
# [CV 1/10; 7/16] START criterion=gini, max_depth=8...............................
# [CV 1/10; 7/16] END criterion=gini, max_depth=8;, score=0.807 total time=   0.0s
# [CV 2/10; 7/16] START criterion=gini, max_depth=8...............................
# [CV 2/10; 7/16] END criterion=gini, max_depth=8;, score=0.851 total time=   0.0s
# [CV 3/10; 7/16] START criterion=gini, max_depth=8...............................
# [CV 3/10; 7/16] END criterion=gini, max_depth=8;, score=0.796 total time=   0.0s
# [CV 4/10; 7/16] START criterion=gini, max_depth=8...............................
# [CV 4/10; 7/16] END criterion=gini, max_depth=8;, score=0.802 total time=   0.0s
# [CV 5/10; 7/16] START criterion=gini, max_depth=8...............................
# [CV 5/10; 7/16] END criterion=gini, max_depth=8;, score=0.779 total time=   0.0s
# [CV 6/10; 7/16] START criterion=gini, max_depth=8...............................
# [CV 6/10; 7/16] END criterion=gini, max_depth=8;, score=0.809 total time=   0.0s
# [CV 7/10; 7/16] START criterion=gini, max_depth=8...............................
# [CV 7/10; 7/16] END criterion=gini, max_depth=8;, score=0.811 total time=   0.0s
# [CV 8/10; 7/16] START criterion=gini, max_depth=8...............................
# [CV 8/10; 7/16] END criterion=gini, max_depth=8;, score=0.802 total time=   0.0s
# [CV 9/10; 7/16] START criterion=gini, max_depth=8...............................
# [CV 9/10; 7/16] END criterion=gini, max_depth=8;, score=0.822 total time=   0.0s
# [CV 10/10; 7/16] START criterion=gini, max_depth=8..............................
# [CV 10/10; 7/16] END criterion=gini, max_depth=8;, score=0.829 total time=   0.0s
# [CV 1/10; 8/16] START criterion=gini, max_depth=9...............................
# [CV 1/10; 8/16] END criterion=gini, max_depth=9;, score=0.796 total time=   0.0s
# [CV 2/10; 8/16] START criterion=gini, max_depth=9...............................
# [CV 2/10; 8/16] END criterion=gini, max_depth=9;, score=0.825 total time=   0.0s
# [CV 3/10; 8/16] START criterion=gini, max_depth=9...............................
# [CV 3/10; 8/16] END criterion=gini, max_depth=9;, score=0.775 total time=   0.0s
# [CV 4/10; 8/16] START criterion=gini, max_depth=9...............................
# [CV 4/10; 8/16] END criterion=gini, max_depth=9;, score=0.789 total time=   0.0s
# [CV 5/10; 8/16] START criterion=gini, max_depth=9...............................
# [CV 5/10; 8/16] END criterion=gini, max_depth=9;, score=0.778 total time=   0.0s
# [CV 6/10; 8/16] START criterion=gini, max_depth=9...............................
# [CV 6/10; 8/16] END criterion=gini, max_depth=9;, score=0.779 total time=   0.0s
# [CV 7/10; 8/16] START criterion=gini, max_depth=9...............................
# [CV 7/10; 8/16] END criterion=gini, max_depth=9;, score=0.815 total time=   0.0s
# [CV 8/10; 8/16] START criterion=gini, max_depth=9...............................
# [CV 8/10; 8/16] END criterion=gini, max_depth=9;, score=0.806 total time=   0.0s
# [CV 9/10; 8/16] START criterion=gini, max_depth=9...............................
# [CV 9/10; 8/16] END criterion=gini, max_depth=9;, score=0.818 total time=   0.0s
# [CV 10/10; 8/16] START criterion=gini, max_depth=9..............................
# [CV 10/10; 8/16] END criterion=gini, max_depth=9;, score=0.823 total time=   0.0s
# [CV 1/10; 9/16] START criterion=entropy, max_depth=2............................
# [CV 1/10; 9/16] END criterion=entropy, max_depth=2;, score=0.742 total time=   0.0s
# [CV 2/10; 9/16] START criterion=entropy, max_depth=2............................
# [CV 2/10; 9/16] END criterion=entropy, max_depth=2;, score=0.788 total time=   0.0s
# [CV 3/10; 9/16] START criterion=entropy, max_depth=2............................
# [CV 3/10; 9/16] END criterion=entropy, max_depth=2;, score=0.776 total time=   0.0s
# [CV 4/10; 9/16] START criterion=entropy, max_depth=2............................
# [CV 4/10; 9/16] END criterion=entropy, max_depth=2;, score=0.754 total time=   0.0s
# [CV 5/10; 9/16] START criterion=entropy, max_depth=2............................
# [CV 5/10; 9/16] END criterion=entropy, max_depth=2;, score=0.766 total time=   0.0s
# [CV 6/10; 9/16] START criterion=entropy, max_depth=2............................
# [CV 6/10; 9/16] END criterion=entropy, max_depth=2;, score=0.758 total time=   0.0s
# [CV 7/10; 9/16] START criterion=entropy, max_depth=2............................
# [CV 7/10; 9/16] END criterion=entropy, max_depth=2;, score=0.780 total time=   0.0s
# [CV 8/10; 9/16] START criterion=entropy, max_depth=2............................
# [CV 8/10; 9/16] END criterion=entropy, max_depth=2;, score=0.772 total time=   0.0s
# [CV 9/10; 9/16] START criterion=entropy, max_depth=2............................
# [CV 9/10; 9/16] END criterion=entropy, max_depth=2;, score=0.747 total time=   0.0s
# [CV 10/10; 9/16] START criterion=entropy, max_depth=2...........................
# [CV 10/10; 9/16] END criterion=entropy, max_depth=2;, score=0.765 total time=   0.0s
# [CV 1/10; 10/16] START criterion=entropy, max_depth=3...........................
# [CV 1/10; 10/16] END criterion=entropy, max_depth=3;, score=0.787 total time=   0.0s
# [CV 2/10; 10/16] START criterion=entropy, max_depth=3...........................
# [CV 2/10; 10/16] END criterion=entropy, max_depth=3;, score=0.845 total time=   0.0s
# [CV 3/10; 10/16] START criterion=entropy, max_depth=3...........................
# [CV 3/10; 10/16] END criterion=entropy, max_depth=3;, score=0.804 total time=   0.0s
# [CV 4/10; 10/16] START criterion=entropy, max_depth=3...........................
# [CV 4/10; 10/16] END criterion=entropy, max_depth=3;, score=0.794 total time=   0.0s
# [CV 5/10; 10/16] START criterion=entropy, max_depth=3...........................
# [CV 5/10; 10/16] END criterion=entropy, max_depth=3;, score=0.818 total time=   0.0s
# [CV 6/10; 10/16] START criterion=entropy, max_depth=3...........................
# [CV 6/10; 10/16] END criterion=entropy, max_depth=3;, score=0.780 total time=   0.0s
# [CV 7/10; 10/16] START criterion=entropy, max_depth=3...........................
# [CV 7/10; 10/16] END criterion=entropy, max_depth=3;, score=0.816 total time=   0.0s
# [CV 8/10; 10/16] START criterion=entropy, max_depth=3...........................
# [CV 8/10; 10/16] END criterion=entropy, max_depth=3;, score=0.820 total time=   0.0s
# [CV 9/10; 10/16] START criterion=entropy, max_depth=3...........................
# [CV 9/10; 10/16] END criterion=entropy, max_depth=3;, score=0.811 total time=   0.0s
# [CV 10/10; 10/16] START criterion=entropy, max_depth=3..........................
# [CV 10/10; 10/16] END criterion=entropy, max_depth=3;, score=0.801 total time=   0.0s
# [CV 1/10; 11/16] START criterion=entropy, max_depth=4...........................
# [CV 1/10; 11/16] END criterion=entropy, max_depth=4;, score=0.787 total time=   0.0s
# [CV 2/10; 11/16] START criterion=entropy, max_depth=4...........................
# [CV 2/10; 11/16] END criterion=entropy, max_depth=4;, score=0.854 total time=   0.0s
# [CV 3/10; 11/16] START criterion=entropy, max_depth=4...........................
# [CV 3/10; 11/16] END criterion=entropy, max_depth=4;, score=0.819 total time=   0.0s
# [CV 4/10; 11/16] START criterion=entropy, max_depth=4...........................
# [CV 4/10; 11/16] END criterion=entropy, max_depth=4;, score=0.809 total time=   0.0s
# [CV 5/10; 11/16] START criterion=entropy, max_depth=4...........................
# [CV 5/10; 11/16] END criterion=entropy, max_depth=4;, score=0.828 total time=   0.0s
# [CV 6/10; 11/16] START criterion=entropy, max_depth=4...........................
# [CV 6/10; 11/16] END criterion=entropy, max_depth=4;, score=0.794 total time=   0.0s
# [CV 7/10; 11/16] START criterion=entropy, max_depth=4...........................
# [CV 7/10; 11/16] END criterion=entropy, max_depth=4;, score=0.828 total time=   0.0s
# [CV 8/10; 11/16] START criterion=entropy, max_depth=4...........................
# [CV 8/10; 11/16] END criterion=entropy, max_depth=4;, score=0.831 total time=   0.0s
# [CV 9/10; 11/16] START criterion=entropy, max_depth=4...........................
# [CV 9/10; 11/16] END criterion=entropy, max_depth=4;, score=0.808 total time=   0.0s
# [CV 10/10; 11/16] START criterion=entropy, max_depth=4..........................
# [CV 10/10; 11/16] END criterion=entropy, max_depth=4;, score=0.818 total time=   0.0s
# [CV 1/10; 12/16] START criterion=entropy, max_depth=5...........................
# [CV 1/10; 12/16] END criterion=entropy, max_depth=5;, score=0.809 total time=   0.0s
# [CV 2/10; 12/16] START criterion=entropy, max_depth=5...........................
# [CV 2/10; 12/16] END criterion=entropy, max_depth=5;, score=0.866 total time=   0.0s
# [CV 3/10; 12/16] START criterion=entropy, max_depth=5...........................
# [CV 3/10; 12/16] END criterion=entropy, max_depth=5;, score=0.818 total time=   0.0s
# [CV 4/10; 12/16] START criterion=entropy, max_depth=5...........................
# [CV 4/10; 12/16] END criterion=entropy, max_depth=5;, score=0.819 total time=   0.0s
# [CV 5/10; 12/16] START criterion=entropy, max_depth=5...........................
# [CV 5/10; 12/16] END criterion=entropy, max_depth=5;, score=0.821 total time=   0.0s
# [CV 6/10; 12/16] START criterion=entropy, max_depth=5...........................
# [CV 6/10; 12/16] END criterion=entropy, max_depth=5;, score=0.797 total time=   0.0s
# [CV 7/10; 12/16] START criterion=entropy, max_depth=5...........................
# [CV 7/10; 12/16] END criterion=entropy, max_depth=5;, score=0.830 total time=   0.0s
# [CV 8/10; 12/16] START criterion=entropy, max_depth=5...........................
# [CV 8/10; 12/16] END criterion=entropy, max_depth=5;, score=0.842 total time=   0.0s
# [CV 9/10; 12/16] START criterion=entropy, max_depth=5...........................
# [CV 9/10; 12/16] END criterion=entropy, max_depth=5;, score=0.828 total time=   0.0s
# [CV 10/10; 12/16] START criterion=entropy, max_depth=5..........................
# [CV 10/10; 12/16] END criterion=entropy, max_depth=5;, score=0.832 total time=   0.0s
# [CV 1/10; 13/16] START criterion=entropy, max_depth=6...........................
# [CV 1/10; 13/16] END criterion=entropy, max_depth=6;, score=0.823 total time=   0.0s
# [CV 2/10; 13/16] START criterion=entropy, max_depth=6...........................
# [CV 2/10; 13/16] END criterion=entropy, max_depth=6;, score=0.868 total time=   0.0s
# [CV 3/10; 13/16] START criterion=entropy, max_depth=6...........................
# [CV 3/10; 13/16] END criterion=entropy, max_depth=6;, score=0.823 total time=   0.0s
# [CV 4/10; 13/16] START criterion=entropy, max_depth=6...........................
# [CV 4/10; 13/16] END criterion=entropy, max_depth=6;, score=0.832 total time=   0.0s
# [CV 5/10; 13/16] START criterion=entropy, max_depth=6...........................
# [CV 5/10; 13/16] END criterion=entropy, max_depth=6;, score=0.833 total time=   0.0s
# [CV 6/10; 13/16] START criterion=entropy, max_depth=6...........................
# [CV 6/10; 13/16] END criterion=entropy, max_depth=6;, score=0.804 total time=   0.0s
# [CV 7/10; 13/16] START criterion=entropy, max_depth=6...........................
# [CV 7/10; 13/16] END criterion=entropy, max_depth=6;, score=0.824 total time=   0.0s
# [CV 8/10; 13/16] START criterion=entropy, max_depth=6...........................
# [CV 8/10; 13/16] END criterion=entropy, max_depth=6;, score=0.839 total time=   0.0s
# [CV 9/10; 13/16] START criterion=entropy, max_depth=6...........................
# [CV 9/10; 13/16] END criterion=entropy, max_depth=6;, score=0.833 total time=   0.0s
# [CV 10/10; 13/16] START criterion=entropy, max_depth=6..........................
# [CV 10/10; 13/16] END criterion=entropy, max_depth=6;, score=0.832 total time=   0.0s
# [CV 1/10; 14/16] START criterion=entropy, max_depth=7...........................
# [CV 1/10; 14/16] END criterion=entropy, max_depth=7;, score=0.826 total time=   0.0s
# [CV 2/10; 14/16] START criterion=entropy, max_depth=7...........................
# [CV 2/10; 14/16] END criterion=entropy, max_depth=7;, score=0.856 total time=   0.0s
# [CV 3/10; 14/16] START criterion=entropy, max_depth=7...........................
# [CV 3/10; 14/16] END criterion=entropy, max_depth=7;, score=0.804 total time=   0.0s
# [CV 4/10; 14/16] START criterion=entropy, max_depth=7...........................
# [CV 4/10; 14/16] END criterion=entropy, max_depth=7;, score=0.820 total time=   0.0s
# [CV 5/10; 14/16] START criterion=entropy, max_depth=7...........................
# [CV 5/10; 14/16] END criterion=entropy, max_depth=7;, score=0.829 total time=   0.0s
# [CV 6/10; 14/16] START criterion=entropy, max_depth=7...........................
# [CV 6/10; 14/16] END criterion=entropy, max_depth=7;, score=0.810 total time=   0.0s
# [CV 7/10; 14/16] START criterion=entropy, max_depth=7...........................
# [CV 7/10; 14/16] END criterion=entropy, max_depth=7;, score=0.835 total time=   0.0s
# [CV 8/10; 14/16] START criterion=entropy, max_depth=7...........................
# [CV 8/10; 14/16] END criterion=entropy, max_depth=7;, score=0.833 total time=   0.0s
# [CV 9/10; 14/16] START criterion=entropy, max_depth=7...........................
# [CV 9/10; 14/16] END criterion=entropy, max_depth=7;, score=0.836 total time=   0.0s
# [CV 10/10; 14/16] START criterion=entropy, max_depth=7..........................
# [CV 10/10; 14/16] END criterion=entropy, max_depth=7;, score=0.835 total time=   0.0s
# [CV 1/10; 15/16] START criterion=entropy, max_depth=8...........................
# [CV 1/10; 15/16] END criterion=entropy, max_depth=8;, score=0.824 total time=   0.0s
# [CV 2/10; 15/16] START criterion=entropy, max_depth=8...........................
# [CV 2/10; 15/16] END criterion=entropy, max_depth=8;, score=0.841 total time=   0.0s
# [CV 3/10; 15/16] START criterion=entropy, max_depth=8...........................
# [CV 3/10; 15/16] END criterion=entropy, max_depth=8;, score=0.805 total time=   0.0s
# [CV 4/10; 15/16] START criterion=entropy, max_depth=8...........................
# [CV 4/10; 15/16] END criterion=entropy, max_depth=8;, score=0.821 total time=   0.0s
# [CV 5/10; 15/16] START criterion=entropy, max_depth=8...........................
# [CV 5/10; 15/16] END criterion=entropy, max_depth=8;, score=0.808 total time=   0.0s
# [CV 6/10; 15/16] START criterion=entropy, max_depth=8...........................
# [CV 6/10; 15/16] END criterion=entropy, max_depth=8;, score=0.797 total time=   0.0s
# [CV 7/10; 15/16] START criterion=entropy, max_depth=8...........................
# [CV 7/10; 15/16] END criterion=entropy, max_depth=8;, score=0.828 total time=   0.0s
# [CV 8/10; 15/16] START criterion=entropy, max_depth=8...........................
# [CV 8/10; 15/16] END criterion=entropy, max_depth=8;, score=0.824 total time=   0.0s
# [CV 9/10; 15/16] START criterion=entropy, max_depth=8...........................
# [CV 9/10; 15/16] END criterion=entropy, max_depth=8;, score=0.809 total time=   0.0s
# [CV 10/10; 15/16] START criterion=entropy, max_depth=8..........................
# [CV 10/10; 15/16] END criterion=entropy, max_depth=8;, score=0.837 total time=   0.0s
# [CV 1/10; 16/16] START criterion=entropy, max_depth=9...........................
# [CV 1/10; 16/16] END criterion=entropy, max_depth=9;, score=0.804 total time=   0.0s
# [CV 2/10; 16/16] START criterion=entropy, max_depth=9...........................
# [CV 2/10; 16/16] END criterion=entropy, max_depth=9;, score=0.823 total time=   0.0s
# [CV 3/10; 16/16] START criterion=entropy, max_depth=9...........................
# [CV 3/10; 16/16] END criterion=entropy, max_depth=9;, score=0.783 total time=   0.0s
# [CV 4/10; 16/16] START criterion=entropy, max_depth=9...........................
# [CV 4/10; 16/16] END criterion=entropy, max_depth=9;, score=0.780 total time=   0.0s
# [CV 5/10; 16/16] START criterion=entropy, max_depth=9...........................
# [CV 5/10; 16/16] END criterion=entropy, max_depth=9;, score=0.780 total time=   0.0s
# [CV 6/10; 16/16] START criterion=entropy, max_depth=9...........................
# [CV 6/10; 16/16] END criterion=entropy, max_depth=9;, score=0.778 total time=   0.0s
# [CV 7/10; 16/16] START criterion=entropy, max_depth=9...........................
# [CV 7/10; 16/16] END criterion=entropy, max_depth=9;, score=0.804 total time=   0.0s
# [CV 8/10; 16/16] START criterion=entropy, max_depth=9...........................
# [CV 8/10; 16/16] END criterion=entropy, max_depth=9;, score=0.800 total time=   0.0s
# [CV 9/10; 16/16] START criterion=entropy, max_depth=9...........................
# [CV 9/10; 16/16] END criterion=entropy, max_depth=9;, score=0.805 total time=   0.0s
# [CV 10/10; 16/16] START criterion=entropy, max_depth=9..........................
# [CV 10/10; 16/16] END criterion=entropy, max_depth=9;, score=0.816 total time=   0.0s
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(random_state=61658),
#              n_jobs=1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4, 5, 6, 7, 8, 9]},
#              scoring='roc_auc', verbose=10)

# %%
grid.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 6}

# %%
grid.best_score_
# Out:
# 0.8310444031434473

# %%
grid.best_estimator_
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, random_state=61658)

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_teste, grid.predict_proba(x_teste)[:,1])
# Out:
# 0.8542399961149961

# %%
df['proba'] = grid.predict_proba(x_final[x_treino.columns])[:,1]
df_pred = df[['CustomerId','proba']]
df_pred

# %%
df_pred.sort_values('proba', ascending=False)
# Out:
#       CustomerId  proba
# 2962    15605000    1.0
# 1193    15779947    1.0
# 4842    15624820    1.0
# 2977    15655123    1.0
# 1117    15592583    1.0
# ...          ...    ...
# 4684    15736963    0.0
# 2173    15649738    0.0
# 526     15600258    0.0
# 6732    15718588    0.0
# 2125    15777923    0.0
#
# [10000 rows x 2 columns]
